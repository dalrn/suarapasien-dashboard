# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Andalan\Documents\Lomba\Satria Data 2026 - Belmawa\data\reviews_all.csv")

# %%
df.columns
# Out:
# Index(['review_id', 'puskesmas_id', 'puskesmas_name', 'puskesmas_title',
#        'wilayah', 'rating', 'review_text', 'reviewer_name', 'review_url',
#        'puskesmas_url', 'source_file', 'text_length', 'is_empty_text',
#        'is_very_short', 'has_rating'],
#       dtype='object')

# %%
df['is_empty_text'].value_counts(normalize=True)
# Out:
# is_empty_text
# False    0.735235
# True     0.264765
# Name: proportion, dtype: float64
